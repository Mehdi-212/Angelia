# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_artistes = pd.read_csv("artistes.csv")
df_chansons = pd.read_csv("chansons.csv")

# %%
df_chansons['years'] = df_chansons['release_date'][0:4]
print(df_chansons['years'])
# Out:
# 0         1922-02-22
# 1         1922-06-01
# 2         1922-03-21
# 3         1922-03-21
# 4                NaN
#              ...
# 586667           NaN
# 586668           NaN
# 586669           NaN
# 586670           NaN
# 586671           NaN
# Name: years, Length: 586672, dtype: object

# %%
sns.heatmap(df_chansons.corr())
# Out:
# <AxesSubplot:>

# %%
heatmap = sns.heatmap(df_chansons.corr(), annot=True)
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12);

# %%
plt.figure(figsize=(8, 12))
heatmap = sns.heatmap(df_artistes.corr()[['popularity']].sort_values(by='popularity', ascending=False), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Features Correlating with popularity artistes', fontdict={'fontsize':18}, pad=16);

# %%
df_par_annees = pd.read_csv("par_annees_o.csv")
df_par_artistes = pd.read_csv("par_artistes_o.csv")
df_par_genres = pd.read_csv("par_genres_o.csv")
df_donnees = pd.read_csv("donnees_o.csv")

# %%
plt.figure(figsize=(8, 12))
heatmap = sns.heatmap(df_par_annees.corr()[['popularity']].sort_values(by='popularity', ascending=False), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Features Correlating with popularity par annees', fontdict={'fontsize':18}, pad=16);

# %%
plt.figure(figsize=(8, 12))
heatmap = sns.heatmap(df_par_genres.corr()[['popularity']].sort_values(by='popularity', ascending=False), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Features Correlating with popularity par genres', fontdict={'fontsize':18}, pad=16);

# %%
plt.figure(figsize=(8, 12))
heatmap = sns.heatmap(df_par_artistes.corr()[['popularity']].sort_values(by='popularity', ascending=False), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Features Correlating with popularity par artistes', fontdict={'fontsize':18}, pad=16);

# %%
plt.figure(figsize=(8, 12))
heatmap = sns.heatmap(df_donnees.corr()[['popularity']].sort_values(by='popularity', ascending=False), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Features Correlating with popularity donnees', fontdict={'fontsize':18}, pad=16);
