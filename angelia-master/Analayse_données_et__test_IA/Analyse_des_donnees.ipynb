# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import seaborn as sns

# %%
df = pd.read_csv("artistes.csv")
df
# Out:
#                              id  followers                 genres  \
# 0        0DheY5irMjBUeLybbCUEZ2        0.0                     []
# 1        0DlhY15l3wsrnlfGio2bjU        5.0                     []
# 2        0DmRESX2JknGPQyO15yxg7        0.0                     []
# 3        0DmhnbHjm1qw6NCYPeZNgJ        0.0                     []
# 4        0Dn11fWM7vHQ3rinvWEl4E        2.0                     []
# ...                         ...        ...                    ...
# 1104344  6rJIG42vcWAf1UBdRFlQxB     3345.0                     []
# 1104345  1ljurfXKPlGncNdW3J8zJ8     2123.0  ['deep acoustic pop']
# 1104346  2vnT9YhKIvjVo9LnVjWmr2       26.0                     []
# 1104347  3ID0E5XCvnJIYZEq043ZoB      406.0                     []
# 1104348  5m0Y4WSYyai2BU752lCASy      146.0                     []
#
#                                                    name  popularity
# 0        Armid & Amir Zare Pashai feat. Sara Rouzbehani           0
# ...

# %%
ef = pd.read_csv("chansons.csv")
ef
# Out:
#                             id                                 name  \
# 0       35iwgR4jXetI318WEWsa1Q                                Carve
# 1       021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 2       07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 3       08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 4       08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
# ...                        ...                                  ...
# 586667  5rgu12WBIHQtvej2MdHSH0                                  云与海
# 586668  0NuWgxEp51CutD2pJoF4OM                                blind
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2            What They'll Say About Us
# 586670  45XJsGpFTyzbzeWK8VzR8S                      A Day At A Time
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn                     Mar de Emociones
#
#         popularity  duration_ms  explicit                          artists  \
# ...

# %%
print(df.isnull().sum())
# Out:
# id             0
# followers     13
# genres         0
# name           0
# popularity     0
# dtype: int64

# %%
print(ef.isnull().sum())
# Out:
# id                   0
# name                71
# popularity           0
# duration_ms          0
# explicit             0
# artists              0
# id_artists           0
# release_date         0
# danceability         0
# energy               0
# key                  0
# loudness             0
# mode                 0
# speechiness          0
# acousticness         0
# instrumentalness     0
# liveness             0
# valence              0
# tempo                0
# time_signature       0
# dtype: int64

# %%
df.loc[df['id'].duplicated(keep=False),:]
# Out:
# Empty DataFrame
# Columns: [id, followers, genres, name, popularity]
# Index: []

# %%
ef.loc[ef['id'].duplicated(keep=False),:]
# Out:
# Empty DataFrame
# Columns: [id, name, popularity, duration_ms, explicit, artists, id_artists, release_date, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, time_signature]
# Index: []

# %%
df['name'].value_counts()
# Out:
# Ace                       12
# Forró Cintura de Mola     12
# Rico                      12
# Luna                      11
# Adam                      10
#                           ..
# August Band                1
# Taladplu Coolplay          1
# Puthachart Sucharitkul     1
# Pango                      1
# 10 Reasons                 1
# Name: name, Length: 1078660, dtype: int64

# %%
ef['artists'].value_counts()
# Out:
# ['Die drei ???']                   3856
# ['TKKG Retro-Archiv']              2006
# ['Benjamin Blümchen']              1503
# ['Bibi Blocksberg']                1472
# ['Lata Mangeshkar']                1373
#                                    ...
# ['IU', 'Jang Yi-jeong']               1
# ['黃宗澤']                               1
# ['Vincy Chan', '海鳴威']                 1
# ['Dough-Boy']                         1
# ['Gentle Bones', 'Clara Benin']       1
# Name: artists, Length: 114030, dtype: int64

# %%
df['popularity'].mean()
# Out:
# 9.083883808469967

# %%
ef['popularity'].mean()
# Out:
# 27.570052772247525

# %%
df.sort_values(by = 'popularity', ascending = False)
# Out:
#                             id   followers  \
# 144481  1uNFoZAHBGtllmzznpCI3s  44606973.0
# 115489  4q3ewBCX7sLwd24euuV69X  32244734.0
# 126338  06HL4z0CvFAxyc27GXpf02  38869193.0
# 313676  3TVXtAsR1Inumwj472S9r4  54416812.0
# 144484  3Nrfpe0tUJi4K4DXYWgMUX  31623813.0
# ...                        ...         ...
# 575721  12fFiEiUzD85RIvyGmlqga        16.0
# 575723  4KcXkP9etxmPNhmYIWaTKn         2.0
# 575724  3HwDYQTG5tE0vULogSTo7Q        29.0
# 575725  2h0LUFqN94Bytz6JMomLYT        19.0
# 552174  6JHLN1SOe8X79KopLtAIDg        14.0
#
#                                                    genres  \
# 144481           ['canadian pop', 'pop', 'post-teen pop']
# 115489              ['latin', 'reggaeton', 'trap latino']
# 126338                           ['pop', 'post-teen pop']
# 313676  ['canadian hip hop', 'canadian pop', 'hip hop'...
# 144484                       ['k-pop', 'k-pop boy group']
# ...                                                   ...
# ...

# %%
ef.sort_values(by = 'popularity', ascending = False)
# Out:
#                             id                                        name  \
# 93802   4iJyoBOLtHqaGxP12qzhQI      Peaches (feat. Daniel Caesar & Giveon)
# 93803   7lPN2DXiMsVn7XUKtOW1CS                             drivers license
# 93804   3Ofmpyhv5UAQ70mENzB277                      Astronaut In The Ocean
# 92810   5QO79kh1waicV47BqGRL3g                             Save Your Tears
# 92811   6tDDoYIxWvMLTdKpjFkc1B                                   telepatía
# ...                        ...                                         ...
# 23410   0sniGbmm1sjg51BxO6AHD4                           O Pardesi Musafir
# 23409   0sk8KA96i9MIU8St2nmbIx               Mere Dil Mein Aao Aur Bas Jao
# 23408   0sdkzsc3WtZIrSi1nNyl7v  Diversions, Op. 21: Variation 9, Toccata I
# 23407   0s6h3lMdJsWkpUAW6xC7m3                                  John Henry
# 444118  4Jb8iDtQk8QgFFMHApIrgK                                 Kevin Barry
#
#         popularity  duration_ms  explicit  \
# ...

# %%
df.sort_values(by = 'popularity', ascending = False)[0:50]
# Out:
#                             id   followers  \
# 144481  1uNFoZAHBGtllmzznpCI3s  44606973.0
# 115489  4q3ewBCX7sLwd24euuV69X  32244734.0
# 126338  06HL4z0CvFAxyc27GXpf02  38869193.0
# 313676  3TVXtAsR1Inumwj472S9r4  54416812.0
# 144484  3Nrfpe0tUJi4K4DXYWgMUX  31623813.0
# 115490  4MCBfE4596Uoi2O4DtmEMz  16996777.0
# 144483  1Xyo4u8uXC1ZmMpatF05PJ  31308207.0
# 144485  66CXWjxzNUsdJxJ2JdwvnR  61301006.0
# 144486  1vyhD5VmyZ7KMfW5gqLgo5  27286822.0
# 115491  7iK8PXO48WeuP03g8YR51W   5001808.0
# 144487  6M2wZ9GZgrQXHCFfjv46we  24123468.0
# 144488  7dGJo4pcD2V6oG8kP0tJRR  43747833.0
# 313813  0Y5tJX1MQlPlqiwlOH1tJY  16118616.0
# 126409  1i8SpTcr7yvPOmcqrbnVXY  27772492.0
# 313701  5f7VJjfbwm532GiveGC0ZK   6789005.0
# 117022  4r63FhuTkUYltbVAg5TQnk   6485079.0
# 144490  0du5cEVh5yTK9QJze8zA0C  29899101.0
# 144489  1mcTU81TzQhprhouKaTkpq   4438013.0
# 145802  246dkjvS1zLTtiykXe5h60  32167665.0
# 144141  2R21vXR83lH98kGeO99Y66  17083706.0
# 126658  6qqNVTkY8uBg9cP3Jd7DAH  41792604.0
# ...

# %%
ef.sort_values(by = 'popularity', ascending = False)[0:50]
# Out:
#                             id  \
# 93802   4iJyoBOLtHqaGxP12qzhQI
# 93803   7lPN2DXiMsVn7XUKtOW1CS
# 93804   3Ofmpyhv5UAQ70mENzB277
# 92810   5QO79kh1waicV47BqGRL3g
# 92811   6tDDoYIxWvMLTdKpjFkc1B
# 93805   7MAibcTli4IisCtbHKrGMh
# 92813   0VjIjW4GlUZAMYd2vXMi3b
# 92814   6f3Slt0GbA2bPZlz0aIFXN
# 92816   3FAJ6O0NOHQV8Mc5Ri6ENp
# 92819   1xK1Gg9SxG8fy2Ya373oqb
# 93807   4cG7HUWYHBV6R6tHn1gxrl
# 93806   7Bk0uXKk1uPT0XuQbpFzvs
# 91866   60ynsPSSKe6O3sfwRnIBRf
# 92817   27OeeYzk6klgBh83TSvGMA
# 92823   3YJJjQPAbDT7mGpX3WtQ9A
# 92821   2XIc1pqjXV3Cr2BQUGNBck
# 93812   3iw6V4LH7yPj1ESORX9RIN
# 92824   47EiUVwUp4C9fGccaPuUCS
# 92826   35mvY5S1H3J2QZyna3TFe0
# 92827   3VvA1wSxukMLsvXoXtlwWx
# 92829   6ft4hAq6yde8jPZY2i5zLr
# 93811   4u4NyuceXP7Uzh7XFJKCr1
# 93809   1XXimziG1uhM0eDNCZCrUl
# 93808   5YYW3yRktprLRr47WK219Y
# 91867   6UelLqGlWMcVH1E5c4H7lY
# 93810   5uEYRdEIh9Bo4fpjDd4Na9
# 92832   45bE4HXI0AwGZXfZtMp8JR
# 92830   4saklk6nie3yiGePpBwUoc
# 92833   7vrJn5hDSXRmdXoR30KgF1
# ...
